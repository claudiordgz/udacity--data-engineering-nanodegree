# %% [markdown]
# # STEP3: Perform some simple data analysis
#
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed steps 1 and 2, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-schema.sql
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila -f Data/pagila-data.sql

# %%
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila
# 'Connected: student@pagila'

# %% [markdown]
# ### 3NF - Entity Relationship Diagram
#
# <img src="./pagila-3nf.png" width="50%"/>
#
# ## 3.1 Insight 1:   Top Grossing Movies
# - Payments amounts are in table `payment`
# - Movies are in table `film`
# - They are not directly linked, `payment` refers to a `rental`, `rental` refers to an `inventory` item and `inventory` item refers to a `film`
# - `payment` &rarr; `rental` &rarr; `inventory` &rarr; `film`

# %% [markdown]
# ### 3.1.1 Films

# %%
# %%sql
# select film_id, title, release_year, rental_rate, rating  from film limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 2006, Decimal('0.99'), 'PG'),
#  (2, 'ACE GOLDFINGER', 2006, Decimal('4.99'), 'G'),
#  (3, 'ADAPTATION HOLES', 2006, Decimal('2.99'), 'NC-17'),
#  (4, 'AFFAIR PREJUDICE', 2006, Decimal('2.99'), 'G'),
#  (5, 'AFRICAN EGG', 2006, Decimal('2.99'), 'G')]

# %% [markdown]
# ### 3.1.2 Payments

# %%
# %%sql
# select * from payment limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(16050, 269, 2, 7, Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (16051, 269, 1, 98, Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (16052, 269, 2, 678, Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (16053, 269, 2, 703, Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (16054, 269, 1, 750, Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)))]

# %% [markdown]
# ### 3.1.3 Inventory

# %%
# %%sql
# select * from inventory limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(1, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (2, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (3, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (4, 1, 1, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None))),
#  (5, 1, 2, datetime.datetime(2017, 2, 15, 10, 9, 17, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)))]

# %% [markdown]
# ### 3.1.4 Get the movie of every payment

# %%
# %%sql
# SELECT f.title, p.amount, p.payment_date, p.customer_id
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [('SWARM GOLD', Decimal('1.99'), datetime.datetime(2017, 1, 24, 21, 40, 19, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 269),
#  ('PACKER MADIGAN', Decimal('0.99'), datetime.datetime(2017, 1, 25, 15, 16, 50, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 269),
#  ('SOMETHING DUCK', Decimal('6.99'), datetime.datetime(2017, 1, 28, 21, 44, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 269),
#  ('DRACULA CRYSTAL', Decimal('0.99'), datetime.datetime(2017, 1, 29, 0, 58, 2, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 269),
#  ('CLOSER BANG', Decimal('4.99'), datetime.datetime(2017, 1, 29, 8, 10, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 269)]

# %% [markdown]
# ### 3.1.5 sum movie rental revenue
# TODO: Write a query that displays the amount of revenue from each title. Limit the results to the top 10 grossing titles. Your results should match the table below.

# %%
# %%sql
# SELECT f.title, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# group by f.title
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('TELEGRAPH VOYAGE', Decimal('231.73')),
#  ('WIFE TURN', Decimal('223.69')),
#  ('ZORRO ARK', Decimal('214.69')),
#  ('GOODFELLAS SALUTE', Decimal('209.69')),
#  ('SATURDAY LAMBS', Decimal('204.72')),
#  ('TITANS JERK', Decimal('201.71')),
#  ('TORQUE BOUND', Decimal('198.72')),
#  ('HARRY IDAHO', Decimal('195.70')),
#  ('INNOCENT USUAL', Decimal('191.74')),
#  ('HUSTLER PARTY', Decimal('190.78'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>title</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>TELEGRAPH VOYAGE</td>
#         <td>231.73</td>
#     </tr>
#     <tr>
#         <td>WIFE TURN</td>
#         <td>223.69</td>
#     </tr>
#     <tr>
#         <td>ZORRO ARK</td>
#         <td>214.69</td>
#     </tr>
#     <tr>
#         <td>GOODFELLAS SALUTE</td>
#         <td>209.69</td>
#     </tr>
#     <tr>
#         <td>SATURDAY LAMBS</td>
#         <td>204.72</td>
#     </tr>
#     <tr>
#         <td>TITANS JERK</td>
#         <td>201.71</td>
#     </tr>
#     <tr>
#         <td>TORQUE BOUND</td>
#         <td>198.72</td>
#     </tr>
#     <tr>
#         <td>HARRY IDAHO</td>
#         <td>195.70</td>
#     </tr>
#     <tr>
#         <td>INNOCENT USUAL</td>
#         <td>191.74</td>
#     </tr>
#     <tr>
#         <td>HUSTLER PARTY</td>
#         <td>190.78</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## 3.2 Insight 2:   Top grossing cities
# - Payments amounts are in table `payment`
# - Cities are in table `cities`
# - `payment` &rarr; `customer` &rarr; `address` &rarr; `city`

# %% [markdown]
# ### 3.2.1 Get the city of each payment

# %%
# %%sql
# SELECT p.customer_id, p.rental_id, p.amount, ci.city
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.payment_date
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [(130, 1, Decimal('2.99'), 'guas Lindas de Gois'),
#  (459, 2, Decimal('2.99'), 'Qomsheh'),
#  (408, 3, Decimal('3.99'), 'Jaffna'),
#  (333, 4, Decimal('4.99'), 'Baku'),
#  (222, 5, Decimal('6.99'), 'Jaroslavl'),
#  (549, 6, Decimal('0.99'), 'Santiago de Compostela'),
#  (269, 7, Decimal('1.99'), 'Salinas'),
#  (239, 8, Decimal('4.99'), 'Ciomas'),
#  (126, 9, Decimal('4.99'), 'Po'),
#  (399, 10, Decimal('5.99'), 'Okara')]

# %% [markdown]
# ### 3.2.2 Top grossing cities
# TODO: Write a query that returns the total amount of revenue by city as measured by the `amount` variable in the `payment` table. Limit the results to the top 10 cities. Your result should match the table below.

# %%
# %%sql
# SELECT ci.city, sum(p.amount) as revenue
# FROM payment p
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by ci.city
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('Cape Coral', Decimal('221.55')),
#  ('Saint-Denis', Decimal('216.54')),
#  ('Aurora', Decimal('198.50')),
#  ('Molodetno', Decimal('195.58')),
#  ('Santa Brbara dOeste', Decimal('194.61')),
#  ('Apeldoorn', Decimal('194.61')),
#  ('Qomsheh', Decimal('186.62')),
#  ('London', Decimal('180.52')),
#  ('Ourense (Orense)', Decimal('177.60')),
#  ('Bijapur', Decimal('175.61'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>Cape Coral</td>
#         <td>221.55</td>
#     </tr>
#     <tr>
#         <td>Saint-Denis</td>
#         <td>216.54</td>
#     </tr>
#     <tr>
#         <td>Aurora</td>
#         <td>198.50</td>
#     </tr>
#     <tr>
#         <td>Molodetno</td>
#         <td>195.58</td>
#     </tr>
#     <tr>
#         <td>Apeldoorn</td>
#         <td>194.61</td>
#     </tr>
#     <tr>
#         <td>Santa Brbara dOeste</td>
#         <td>194.61</td>
#     </tr>
#     <tr>
#         <td>Qomsheh</td>
#         <td>186.62</td>
#     </tr>
#     <tr>
#         <td>London</td>
#         <td>180.52</td>
#     </tr>
#     <tr>
#         <td>Ourense (Orense)</td>
#         <td>177.60</td>
#     </tr>
#     <tr>
#         <td>Bijapur</td>
#         <td>175.61</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## 3.3 Insight 3 : Revenue of a movie by customer city and by month

# %% [markdown]
# ### 3.3.1 Total revenue by month

# %%
# %%sql
# SELECT sum(p.amount) as revenue, EXTRACT(month FROM p.payment_date) as month
# from payment p
# group by month
# order by revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(Decimal('28559.46'), 4.0),
#  (Decimal('23886.56'), 3.0),
#  (Decimal('9631.88'), 2.0),
#  (Decimal('4824.43'), 1.0),
#  (Decimal('514.18'), 5.0)]

# %% [markdown]
# ### 3.3.2 Each movie by customer city and by month (data cube)

# %%
# %%sql
# SELECT f.title, p.amount, p.customer_id, ci.city, p.payment_date,EXTRACT(month FROM p.payment_date) as month
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# order by p.amount desc
# limit 50;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 50 rows affected.
# [('VIRTUAL SPOILERS', Decimal('11.99'), 305, 'Arlington', datetime.datetime(2017, 2, 17, 22, 19, 47, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('STING PERSONAL', Decimal('11.99'), 362, 'Belm', datetime.datetime(2017, 3, 21, 21, 57, 24, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('MINE TITANS', Decimal('11.99'), 591, 'Juiz de Fora', datetime.datetime(2017, 4, 7, 19, 14, 17, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 4.0),
#  ('SHOW LORD', Decimal('11.99'), 196, 'Mannheim', datetime.datetime(2017, 1, 25, 16, 46, 45, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 1.0),
#  ('TIES HUNGER', Decimal('11.99'), 237, 'Naju', datetime.datetime(2017, 3, 2, 20, 46, 39, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('MIDSUMMER GROUNDHOG', Decimal('11.99'), 592, 'Szkesfehrvr', datetime.datetime(2017, 4, 6, 21, 26, 57, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 4.0),
#  ('SCORPION APOLLO', Decimal('11.99'), 13, 'Osmaniye', datetime.datetime(2017, 4, 29, 21, 6, 7, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 4.0),
#  ('TRAP GUYS', Decimal('11.99'), 204, 'Usak', datetime.datetime(2017, 3, 22, 22, 17, 22, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('FLINTSTONES HAPPINESS', Decimal('11.99'), 116, 'Pemalang', datetime.datetime(2017, 3, 21, 22, 2, 26, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('SCORPION APOLLO', Decimal('11.99'), 195, 'Siegen', datetime.datetime(2017, 3, 23, 20, 47, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('TYCOON GATHERING', Decimal('10.99'), 567, 'Serpuhov', datetime.datetime(2017, 3, 23, 4, 47, 9, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('AMERICAN CIRCUS', Decimal('10.99'), 545, 'Konotop', datetime.datetime(2017, 3, 18, 17, 40, 11, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('GARDEN ISLAND', Decimal('10.99'), 565, 'Hunuco', datetime.datetime(2017, 3, 1, 19, 28, 24, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('TYCOON GATHERING', Decimal('10.99'), 544, 'So Bernardo do Campo', datetime.datetime(2017, 2, 15, 16, 59, 12, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('DOORS PRESIDENT', Decimal('10.99'), 550, 'Zhoushan', datetime.datetime(2017, 2, 21, 3, 46, 53, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('FOOL MOCKINGBIRD', Decimal('10.99'), 526, 'Cape Coral', datetime.datetime(2017, 3, 16, 21, 39, 0, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('VIRTUAL SPOILERS', Decimal('10.99'), 550, 'Zhoushan', datetime.datetime(2017, 3, 19, 9, 55, 58, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('CARIBBEAN LIBERTY', Decimal('10.99'), 457, 'Rockford', datetime.datetime(2017, 3, 21, 6, 46, 44, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('SUIT WALLS', Decimal('10.99'), 347, 'Daugavpils', datetime.datetime(2017, 3, 18, 7, 42, 8, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('TITANIC BOONDOCK', Decimal('10.99'), 345, 'San Lorenzo', datetime.datetime(2017, 3, 21, 19, 28, 29, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('MINDS TRUMAN', Decimal('10.99'), 388, 'Cavite', datetime.datetime(2017, 3, 21, 4, 55, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('NIGHTMARE CHILL', Decimal('10.99'), 420, 'El Monte', datetime.datetime(2017, 3, 1, 12, 54, 6, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('CASUALTIES ENCINO', Decimal('10.99'), 276, 'Warren', datetime.datetime(2017, 1, 30, 1, 13, 42, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 1.0),
#  ('FOOL MOCKINGBIRD', Decimal('10.99'), 470, 'Hodeida', datetime.datetime(2017, 3, 18, 21, 6, 5, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('BILKO ANONYMOUS', Decimal('10.99'), 529, 'Bhimavaram', datetime.datetime(2017, 3, 1, 4, 22, 15, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('STING PERSONAL', Decimal('10.99'), 531, 'Kuwana', datetime.datetime(2017, 3, 2, 12, 34, 8, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('SATISFACTION CONFIDENTIAL', Decimal('10.99'), 511, 'Suihua', datetime.datetime(2017, 2, 20, 6, 7, 59, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('TELEGRAPH VOYAGE', Decimal('10.99'), 562, 'Sokoto', datetime.datetime(2017, 3, 19, 18, 57, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('BEHAVIOR RUNAWAY', Decimal('10.99'), 516, 'Battambang', datetime.datetime(2017, 2, 16, 13, 20, 28, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('TELEGRAPH VOYAGE', Decimal('10.99'), 542, 'Pangkal Pinang', datetime.datetime(2017, 2, 20, 5, 22, 13, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('TITANIC BOONDOCK', Decimal('10.99'), 367, 'Adoni', datetime.datetime(2017, 3, 21, 12, 9, 40, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('TRAP GUYS', Decimal('10.99'), 459, 'Qomsheh', datetime.datetime(2017, 3, 20, 16, 44, 52, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('TORQUE BOUND', Decimal('10.99'), 292, 'Sharja', datetime.datetime(2017, 3, 18, 20, 43, 44, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('TELEGRAPH VOYAGE', Decimal('10.99'), 433, 'Naala-Porto', datetime.datetime(2017, 1, 28, 23, 29, 52, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 1.0),
#  ('KISSING DOLLS', Decimal('10.99'), 289, 'Kowloon and New Kowloon', datetime.datetime(2017, 2, 19, 17, 8, 55, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('VIRTUAL SPOILERS', Decimal('10.99'), 221, 'Syrakusa', datetime.datetime(2017, 2, 19, 9, 18, 28, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('TELEGRAPH VOYAGE', Decimal('10.99'), 260, 'Datong', datetime.datetime(2017, 2, 17, 16, 37, 30, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('DAUGHTER MADIGAN', Decimal('10.99'), 277, 'Ogbomosho', datetime.datetime(2017, 3, 22, 6, 52, 58, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('SUNRISE LEAGUE', Decimal('10.99'), 336, 'Rampur', datetime.datetime(2017, 3, 22, 9, 29, 41, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('AMERICAN CIRCUS', Decimal('10.99'), 304, 'Callao', datetime.datetime(2017, 1, 25, 20, 27, 24, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 1.0),
#  ('WIFE TURN', Decimal('10.99'), 297, 'Ahmadnagar', datetime.datetime(2017, 3, 18, 10, 27, 14, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('STRANGER STRANGERS', Decimal('10.99'), 572, 'Czestochowa', datetime.datetime(2017, 2, 17, 2, 33, 38, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('CARIBBEAN LIBERTY', Decimal('10.99'), 371, 'Cabuyao', datetime.datetime(2017, 3, 2, 6, 7, 10, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('MINDS TRUMAN', Decimal('10.99'), 372, 'Probolinggo', datetime.datetime(2017, 3, 2, 7, 47, 48, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('BEAST HUNCHBACK', Decimal('10.99'), 404, 'Omiya', datetime.datetime(2017, 3, 22, 17, 56, 28, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-420, name=None)), 3.0),
#  ('SHOW LORD', Decimal('10.99'), 410, 'Richmond Hill', datetime.datetime(2017, 3, 2, 9, 44, 45, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('TRAP GUYS', Decimal('10.99'), 21, 'Tangail', datetime.datetime(2017, 2, 20, 23, 33, 1, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('AUTUMN CROW', Decimal('10.99'), 477, 'Stockport', datetime.datetime(2017, 2, 18, 7, 1, 49, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0),
#  ('AMERICAN CIRCUS', Decimal('10.99'), 468, 'Bijapur', datetime.datetime(2017, 3, 2, 12, 13, 31, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 3.0),
#  ('SATURDAY LAMBS', Decimal('10.99'), 558, 'Wroclaw', datetime.datetime(2017, 2, 21, 19, 39, 5, 996577, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=-480, name=None)), 2.0)]

# %% [markdown]
# ### 3.3.3 Sum of revenue of each movie by customer city and by month
#
# TODO: Write a query that returns the total amount of revenue for each movie by customer city and by month. Limit the results to the top 10 movies. Your result should match the table below.

# %%
# %%sql
# SELECT f.title, ci.city, EXTRACT(month FROM p.payment_date) as month, sum(p.amount) as revenue
# FROM payment p
# JOIN rental r    ON ( p.rental_id = r.rental_id )
# JOIN inventory i ON ( r.inventory_id = i.inventory_id )
# JOIN film f ON ( i.film_id = f.film_id)
# JOIN customer c  ON ( p.customer_id = c.customer_id )
# JOIN address a ON ( c.address_id = a.address_id )
# JOIN city ci ON ( a.city_id = ci.city_id )
# group by (f.title, ci.city, month)
# order by month, revenue desc
# limit 10;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila
# 10 rows affected.
# [('SHOW LORD', 'Mannheim', 1.0, Decimal('11.99')),
#  ('CASUALTIES ENCINO', 'Warren', 1.0, Decimal('10.99')),
#  ('KISSING DOLLS', 'Toulon', 1.0, Decimal('10.99')),
#  ('AMERICAN CIRCUS', 'Callao', 1.0, Decimal('10.99')),
#  ('TELEGRAPH VOYAGE', 'Naala-Porto', 1.0, Decimal('10.99')),
#  ('STRANGER STRANGERS', 'Ipoh', 1.0, Decimal('9.99')),
#  ('HEAD STRANGER', 'Xiangtan', 1.0, Decimal('9.99')),
#  ('MISSION ZOOLANDER', 'Abha', 1.0, Decimal('9.99')),
#  ('MILLION ACE', 'Gaziantep', 1.0, Decimal('9.99')),
#  ('DARKO DORADO', 'Bhilwara', 1.0, Decimal('9.99'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>title</th>
#         <th>city</th>
#         <th>month</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>SHOW LORD</td>
#         <td>Mannheim</td>
#         <td>1.0</td>
#         <td>11.99</td>
#     </tr>
#     <tr>
#         <td>AMERICAN CIRCUS</td>
#         <td>Callao</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>CASUALTIES ENCINO</td>
#         <td>Warren</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>TELEGRAPH VOYAGE</td>
#         <td>Naala-Porto</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>KISSING DOLLS</td>
#         <td>Toulon</td>
#         <td>1.0</td>
#         <td>10.99</td>
#     </tr>
#     <tr>
#         <td>MILLION ACE</td>
#         <td>Bergamo</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>TITANS JERK</td>
#         <td>Kimberley</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>DARKO DORADO</td>
#         <td>Bhilwara</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>SUNRISE LEAGUE</td>
#         <td>Nagareyama</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
#     <tr>
#         <td>MILLION ACE</td>
#         <td>Gaziantep</td>
#         <td>1.0</td>
#         <td>9.99</td>
#     </tr>
# </tbody></table></div>
